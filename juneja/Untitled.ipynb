# %%
import torch

print(torch.__version__)
# Out:
# 1.12.1+cu113

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- ------------------
# absl-py                      1.4.0
# alembic                      1.7.1
# antlr4-python3-runtime       4.9.3
# argon2-cffi                  21.1.0
# astunparse                   1.6.3
# async-generator              1.10
# attrs                        21.2.0
# backcall                     0.2.0
# black                        23.3.0
# bleach                       4.1.0
# cachetools                   5.3.1
# certifi                      2022.12.7
# certipy                      0.1.3
# cffi                         1.14.6
# charset-normalizer           3.1.0
# click                        8.1.3
# cloudpickle                  2.2.1
# contourpy                    1.0.7
# cryptography                 3.4.8
# cycler                       0.11.0
# dbus-python                  1.2.16
# debugpy                      1.4.1
# decorator                    5.0.9
# defusedxml                   0.7.1
# detectron2                   0.6
# docopt                       0.6.2
# entrypoints                  0.3
# flatbuffers                  23.5.26
# fonttools                    4.39.4
# fvcore                       0.1.5.post20221221
# gast                         0.4.0
# google-auth                  2.19.1
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# graphsurgeon                 0.4.5
# greenlet                     1.1.1
# grpcio                       1.54.2
# h5py                         3.8.0
# hydra-core                   1.3.2
# idna                         3.4
# importlib-metadata           6.6.0
# importlib-resources          5.12.0
# iopath                       0.1.9
# ipykernel                    6.3.1
# ipython                      7.27.0
# ipython-genutils             0.2.0
# ipywidgets                   7.6.4
# jedi                         0.18.0
# Jinja2                       3.0.1
# jsonschema                   3.2.0
# jupyter                      1.0.0
# jupyter-client               7.0.2
# jupyter-console              6.4.0
# jupyter-core                 4.7.1
# jupyter-telemetry            0.1.0
# jupyterhub                   1.4.2
# jupyterlab-pygments          0.1.2
# jupyterlab-widgets           1.0.1
# keras                        2.11.0
# kiwisolver                   1.4.4
# libclang                     16.0.0
# Mako                         1.1.5
# Markdown                     3.4.3
# MarkupSafe                   2.1.3
# matplotlib                   3.7.1
# matplotlib-inline            0.1.3
# mistune                      0.8.4
# mypy-extensions              1.0.0
# nbclient                     0.5.4
# nbconvert                    6.1.0
# nbformat                     5.1.3
# nest-asyncio                 1.5.1
# netifaces                    0.10.4
# notebook                     6.4.3
# numpy                        1.24.3
# oauthlib                     3.2.2
# omegaconf                    2.3.0
# onnx-graphsurgeon            0.3.10
# opt-einsum                   3.3.0
# packaging                    23.1
# pamela                       1.0.0
# pandocfilters                1.4.3
# parso                        0.8.2
# pathspec                     0.11.1
# pexpect                      4.8.0
# pickleshare                  0.7.5
# Pillow                       9.5.0
# pip                          21.2.4
# pipreqs                      0.4.11
# platformdirs                 3.5.1
# ply                          3.11
# portalocker                  2.7.0
# prometheus-client            0.11.0
# prompt-toolkit               3.0.20
# protobuf                     3.19.6
# ptyprocess                   0.7.0
# pyasn1                       0.5.0
# pyasn1-modules               0.3.0
# pycocotools                  2.0.6
# pycparser                    2.20
# Pygments                     2.10.0
# PyGObject                    3.36.0
# pymacaroons                  0.13.0
# PyNaCl                       1.3.0
# pyOpenSSL                    20.0.1
# pyparsing                    3.0.9
# pyrsistent                   0.18.0
# python-dateutil              2.8.2
# python-json-logger           2.0.2
# PyYAML                       5.3.1
# pyzmq                        22.2.1
# qtconsole                    5.1.1
# QtPy                         1.11.0
# requests                     2.28.2
# requests-oauthlib            1.3.1
# rsa                          4.9
# ruamel.yaml                  0.17.16
# ruamel.yaml.clib             0.2.6
# Send2Trash                   1.8.0
# setuptools                   45.2.0
# six                          1.14.0
# SQLAlchemy                   1.4.23
# sudospawner                  0.6.0.dev0
# tabulate                     0.9.0
# tensorboard                  2.11.2
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.11.0
# tensorflow-estimator         2.11.0
# tensorflow-io-gcs-filesystem 0.32.0
# tensorrt                     8.0.1.6
# termcolor                    2.3.0
# terminado                    0.12.1
# testpath                     0.5.0
# tomli                        2.0.1
# torch                        1.12.1+cu113
# torchaudio                   0.12.1+cu113
# torchvision                  0.13.1+cu113
# tornado                      6.1
# tqdm                         4.65.0
# traitlets                    5.1.0
# typing_extensions            4.6.3
# uff                          0.6.9
# urllib3                      1.26.15
# wcwidth                      0.2.5
# webencodings                 0.5.1
# Werkzeug                     2.3.4
# wheel                        0.34.2
# widgetsnbextension           3.5.1
# wrapt                        1.15.0
# yacs                         0.1.8
# yarg                         0.1.9
# zipp                         3.15.0

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Mon_May__3_19:15:13_PDT_2021
# Cuda compilation tools, release 11.3, V11.3.109
# Build cuda_11.3.r11.3/compiler.29920130_0

# %%
# !nvidia-smi
# Out:
# Sat Jun  3 18:48:02 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.60.13    Driver Version: 525.60.13    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:B1:00.0 Off |                  N/A |
# | 22%   24C    P8     5W / 250W |  11007MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  Off  | 00000000:B2:00.0 Off |                  N/A |
# | 22%   24C    P8     1W / 250W |    667MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA GeForce ...  Off  | 00000000:DA:00.0 Off |                  N/A |
# | 22%   24C    P8    16W / 250W |   1861MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA GeForce ...  Off  | 00000000:DB:00.0 Off |                  N/A |
# | 22%   24C    P8    20W / 250W |    999MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, random

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# %%
# !nvidia-smi
# Out:
# Sun Jun  4 07:36:17 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.60.13    Driver Version: 525.60.13    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:B1:00.0 Off |                  N/A |
# | 22%   24C    P8     5W / 250W |  11007MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  Off  | 00000000:B2:00.0 Off |                  N/A |
# | 22%   24C    P8     1W / 250W |    667MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA GeForce ...  Off  | 00000000:DA:00.0 Off |                  N/A |
# | 22%   24C    P8    16W / 250W |    667MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA GeForce ...  Off  | 00000000:DB:00.0 Off |                  N/A |
# | 22%   24C    P8    21W / 250W |    667MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
